# %%
import pandas as pd

# %%
#Load the dataset
df =pd.read_csv('/content/100_Unique_QA_Dataset.csv')
df.head()
# Out:
#                                           question      answer
# 0                   What is the capital of France?       Paris
# 1                  What is the capital of Germany?      Berlin
# 2               Who wrote 'To Kill a Mockingbird'?  Harper-Lee
# 3  What is the largest planet in our solar system?     Jupiter
# 4   What is the boiling point of water in Celsius?         100

# %%
#tokenize
def tokenize(text):
   text = text.lower()
   text = text.replace('?','')
   text = text.replace("","")
   return text.split()

# %%
tokenize( "what is the capital of Germany")
# Out:
# ['what', 'is', 'the', 'capital', 'of', 'germany']

# %%
#Vocab
vocab ={'<UNK>':0}

# %%
def build_vocab(row):
  print(row['question'], row['answer'])
  tokenize_questions = tokenize(row['question'])
  tokenize_answer = tokenize(row['answer'])
  merge_tokenize = tokenize_questions + tokenize_answer

  for token in merge_tokenize:
    if token not in vocab:
      vocab[token] = len(vocab)

# %%
df.apply(build_vocab, axis=1)
# Out:
# What is the capital of France? Paris
# What is the capital of Germany? Berlin
# Who wrote 'To Kill a Mockingbird'? Harper-Lee
# What is the largest planet in our solar system? Jupiter
# What is the boiling point of water in Celsius? 100
# Who painted the Mona Lisa? Leonardo-da-Vinci
# What is the square root of 64? 8
# What is the chemical symbol for gold? Au
# Which year did World War II end? 1945
# What is the longest river in the world? Nile
# What is the capital of Japan? Tokyo
# Who developed the theory of relativity? Albert-Einstein
# What is the freezing point of water in Fahrenheit? 32
# Which planet is known as the Red Planet? Mars
# Who is the author of '1984'? George-Orwell
# What is the currency of the United Kingdom? Pound
# What is the capital of India? Delhi
# Who discovered gravity? Newton
# How many continents are there on Earth? 7
# Which gas do plants use for photosynthesis? CO2
# What is the smallest prime number? 2
# Who invented the telephone? Alexander-Graham-Bell
# What is the capital of Australia? Canberra
# Which ocean is the largest? Pacific-Ocean
# What is the speed of light in vacuum? 299,792,458m/s
# Which language is spoken in Brazil? Portuguese
# Who discovered penicillin? Alexander-Fleming
# What is the capital of Canada? Ottawa
# What is the largest mammal on Earth? Whale
# Which element has the atomic number 1? Hydrogen
# What is the tallest mountain in the world? Everest
# Which city is known as the Big Apple? NewYork
# How many planets are in the Solar System? 8
# Who painted 'Starry Night'? vangogh
# What is the chemical formula of water? H2O
# What is the capital of Italy? Rome
# Which country is famous for sushi? Japan
# Who was the first person to step on the Moon? Armstrong
# What is the main ingredient in guacamole? Avocado
# How many sides does a hexagon have? 6
# What is the currency of China? Yuan
# Who wrote 'Pride and Prejudice'? Jane-Austen
# What is the chemical symbol for iron? Fe
# What is the hardest natural substance on Earth? Diamond
# Which continent is the largest by area? Asia
# Who was the first President of the United States? George-Washington
# Which bird is known for its ability to mimic sounds? Parrot
# What is the longest-running animated TV show? Simpsons
# What is the smallest country in the world? VaticanCity
# Which planet has the most moons? Saturn
# Who wrote 'Romeo and Juliet'? Shakespeare
# What is the main gas in Earth's atmosphere? Nitrogen
# How many bones are in the adult human body? 206
# Which metal is a liquid at room temperature? Mercury
# What is the capital of Russia? Moscow
# Who discovered electricity? Benjamin-Franklin
# Which is the second-largest country by land area? Canada
# What is the color of a ripe banana? Yellow
# Which month has 28 days in a common year? February
# What is the study of living organisms called? Biology
# Which country is home to the Great Wall? China
# What do bees collect from flowers? Nectar
# What is the opposite of 'day'? Night
# What is the capital of South Korea? Seoul
# Who invented the light bulb? Edison
# Which gas do humans breathe in for survival? Oxygen
# What is the square root of 144? 12
# Which country has the pyramids of Giza? Egypt
# Which sea creature has eight arms? Octopus
# Which holiday is celebrated on December 25? Christmas
# What is the currency of Japan? Yen
# How many legs does a spider have? 8
# Which sport uses a net, ball, and hoop? Basketball
# Which country is famous for its kangaroos? Australia
# Who was the first female Prime Minister of the UK? MargaretThatcher
# Which is the fastest land animal? Cheetah
# What is the first element on the periodic table? Hydrogen
# What is the capital of Spain? Madrid
# Which planet is the closest to the Sun? Mercury
# Who is known as the father of computers? CharlesBabbage
# What is the capital of Mexico? MexicoCity
# How many colors are in a rainbow? 7
# Which musical instrument has black and white keys? Piano
# Who discovered the Americas in 1492? ChristopherColumbus
# Which Disney character has a long nose and grows it when lying? Pinocchio
# Who directed the movie 'Titanic'? JamesCameron
# Which superhero is also known as the Dark Knight? Batman
# What is the capital of Brazil? Brasilia
# Which fruit is known as the king of fruits? Mango
# Which country is known for the Eiffel Tower? France
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 85    None
# 86    None
# 87    None
# 88    None
# 89    None
# Length: 90, dtype: object

# %%
len(vocab)
# Out:
# 326

# %%
#convert text to numerical

def text_to_numerical(sentence,vocab):
  indexed_text = []
  for token in tokenize(sentence):
    if token in vocab:
      indexed_text.append(vocab[token])
    else:
      indexed_text.append(vocab['<UNK>'])
  return indexed_text

# %%
text_to_numerical("what is campusx",vocab)
# Out:
# [1, 2, 0]

# %%
from torch.utils.data import Dataset,DataLoader
import torch

class QADataset(Dataset):
    def __init__(self, df, vocab):
        self.df = df
        self.vocab = vocab

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        question = self.df.iloc[index]['question']
        answer = self.df.iloc[index]['answer']

        numerical_question = text_to_numerical(question, self.vocab)
        numerical_answer = text_to_numerical(answer, self.vocab)

        return (
            torch.tensor(numerical_question, dtype=torch.long),
            torch.tensor(numerical_answer, dtype=torch.long)
        )

# %%
dataset = QADataset(df,vocab)

# %%
dataloader = DataLoader(dataset,batch_size=1,shuffle=True)

# %%
for question, answer in dataloader:
  print(question,answer)
# Out:
# tensor([[ 1,  2,  3, 50, 51, 19,  3, 45]]) tensor([[52]])
# tensor([[  1,   2,   3, 222,   5, 223, 224, 225]]) tensor([[226]])
# tensor([[ 42, 301, 302, 118,  14, 303, 304, 159, 305, 306, 307, 308]]) tensor([[309]])
# tensor([[ 10,  96,   3, 104, 241]]) tensor([[242]])
# tensor([[ 1,  2,  3, 17, 18, 19, 20, 21, 22]]) tensor([[23]])
# tensor([[  1,   2,   3, 103,   5, 104,  19, 105]]) tensor([[106]])
# tensor([[ 10,  29, 130, 131]]) tensor([[132]])
# tensor([[ 1,  2,  3, 59, 25,  5, 26, 19, 60]]) tensor([[61]])
# tensor([[  1,   2,   3, 235,   5, 236]]) tensor([[237]])
# tensor([[ 78,  79, 151, 152,  14, 153, 154]]) tensor([[155]])
# tensor([[  1,   2,   3,  69,   5, 156]]) tensor([[157]])
# tensor([[  1,   2,   3, 147, 148,  19, 149]]) tensor([[150]])
# tensor([[  1,   2,   3,   4,   5, 288]]) tensor([[289]])
# tensor([[ 10, 140,   3, 141, 172,   5,   3,  70, 173]]) tensor([[174]])
# tensor([[ 42,   2,   3, 276, 212, 277]]) tensor([[278]])
# tensor([[ 1,  2,  3, 37, 38, 39, 40]]) tensor([[41]])
# tensor([[ 42, 137,   2, 138,  39, 176, 271]]) tensor([[99]])
# tensor([[ 10,  11, 190, 159, 191]]) tensor([[192]])
# tensor([[  1,   2,   3,   4,   5, 135]]) tensor([[136]])
# tensor([[ 1,  2,  3, 69,  5,  3, 70, 71]]) tensor([[72]])
# tensor([[42, 86, 87, 88, 89, 39, 90]]) tensor([[91]])
# tensor([[  1,   2,   3,   4,   5, 281]]) tensor([[282]])
# tensor([[ 10,  75, 111]]) tensor([[112]])
# tensor([[  1,   2,   3, 164, 165, 166,  83,  84]]) tensor([[167]])
# tensor([[  1,   2,   3,  37, 133,   5,  26]]) tensor([[134]])
# tensor([[ 1,  2,  3, 92, 93, 94]]) tensor([[95]])
# tensor([[42, 43, 44, 45, 46, 47, 48]]) tensor([[49]])
# tensor([[ 42,  86,  87, 243, 244,  19,  39, 245]]) tensor([[246]])
# tensor([[  1,  87, 230, 231, 232, 233]]) tensor([[234]])
# tensor([[ 42, 125,   2,  62,  63,   3, 126, 127]]) tensor([[128]])
# tensor([[ 78,  79, 129,  81,  19,   3,  21,  22]]) tensor([[36]])
# tensor([[  1,   2,   3,  33,  34,   5, 247]]) tensor([[248]])
# tensor([[ 42, 168,   2,   3,  17, 169, 170]]) tensor([[171]])
# tensor([[ 42, 314,   2, 315,  62,  63,   3, 316, 317]]) tensor([[318]])
# tensor([[ 42, 137,   2, 138,  39, 139]]) tensor([[53]])
# tensor([[ 10,  75, 209]]) tensor([[210]])
# tensor([[ 42, 217, 118, 218, 219,  19,  14, 220,  43]]) tensor([[221]])
# tensor([[ 10, 310,   3, 311, 312]]) tensor([[313]])
# tensor([[10, 55,  3, 56,  5, 57]]) tensor([[58]])
# tensor([[  1,   2,   3,   4,   5, 238, 239]]) tensor([[240]])
# tensor([[ 42, 292, 293, 118, 294, 159, 295, 296]]) tensor([[297]])
# tensor([[1, 2, 3, 4, 5, 8]]) tensor([[9]])
# tensor([[ 42, 107,   2, 108,  19, 109]]) tensor([[110]])
# tensor([[ 42, 265, 266,  14, 267, 268, 159, 269]]) tensor([[270]])
# tensor([[10, 96,  3, 97]]) tensor([[98]])
# tensor([[ 42, 137,   2, 227, 143,   3, 228, 229]]) tensor([[156]])
# tensor([[  1,   2,   3, 213,   5,  14, 214, 215]]) tensor([[216]])
# tensor([[  1,   2,   3, 141, 117,  83,   3, 279, 280]]) tensor([[121]])
# tensor([[ 42, 101,   2,   3,  17]]) tensor([[102]])
# tensor([[ 78,  79, 290,  81,  19,  14, 291]]) tensor([[85]])
# tensor([[ 10,  11, 158, 159, 160]]) tensor([[161]])
# tensor([[  1,   2,   3,  17, 115,  83,  84]]) tensor([[116]])
# tensor([[ 42, 252, 253, 118, 254, 255]]) tensor([[256]])
# tensor([[  1,   2,   3,  37,  38,  39, 162]]) tensor([[163]])
# tensor([[ 10, 140,   3, 141, 272,  93, 273,   5,   3, 274]]) tensor([[275]])
# tensor([[42, 18,  2, 62, 63,  3, 64, 18]]) tensor([[65]])
# tensor([[ 78,  79, 263, 152,  14, 264, 154]]) tensor([[36]])
# tensor([[ 42,  18,   2,   3, 283, 143,   3, 284]]) tensor([[206]])
# tensor([[10,  2,  3, 66,  5, 67]]) tensor([[68]])
# tensor([[10, 75, 76]]) tensor([[77]])
# tensor([[ 10, 140,   3, 141, 142, 143, 144,  83,   3, 145]]) tensor([[146]])
# tensor([[ 10,  75,   3, 298,  19, 299]]) tensor([[300]])
# tensor([[  1,   2,   3,   4,   5, 109]]) tensor([[319]])
# tensor([[ 42, 137,   2,  62,  39,   3, 324, 325]]) tensor([[6]])
# tensor([[  1,   2,   3, 147,  86,  19, 193, 194]]) tensor([[195]])
# tensor([[78, 79, 80, 81, 82, 83, 84]]) tensor([[85]])
# tensor([[10, 11, 12, 13, 14, 15]]) tensor([[16]])
# tensor([[ 1,  2,  3, 69,  5, 53]]) tensor([[262]])
# tensor([[ 42, 257,   2, 258,  83, 259, 260]]) tensor([[261]])
# tensor([[ 42,   2,   3, 211, 137, 169, 212, 170]]) tensor([[113]])
# tensor([[ 42, 201,   2,  14, 202, 203, 204, 205]]) tensor([[206]])
# tensor([[  1,   2,   3,   4,   5, 113]]) tensor([[114]])
# tensor([[ 42, 137, 118,   3, 249,   5, 250]]) tensor([[251]])
# tensor([[ 78,  79, 196,  81,  19,   3, 197, 198, 199]]) tensor([[200]])
# tensor([[ 10,   2,  62,  63,   3, 285,   5, 286]]) tensor([[287]])
# tensor([[ 1,  2,  3,  4,  5, 53]]) tensor([[54]])
# tensor([[ 42, 175,   2,  62,  39, 176, 177, 143, 178, 179]]) tensor([[180]])
# tensor([[ 42, 320,   2,  62,  63,   3, 321,   5, 322]]) tensor([[323]])
# tensor([[ 1,  2,  3, 33, 34,  5, 35]]) tensor([[36]])
# tensor([[10, 29,  3, 30, 31]]) tensor([[32]])
# tensor([[1, 2, 3, 4, 5, 6]]) tensor([[7]])
# tensor([[  1,   2,   3,   4,   5, 207]]) tensor([[208]])
# tensor([[  1,   2,   3,  92, 137,  19,   3,  45]]) tensor([[186]])
# tensor([[ 1,  2,  3, 24, 25,  5, 26, 19, 27]]) tensor([[28]])
# tensor([[ 42,  18, 118,   3, 187, 188]]) tensor([[189]])
# tensor([[ 1,  2,  3,  4,  5, 73]]) tensor([[74]])
# tensor([[  1,   2,   3, 181, 182, 183, 184]]) tensor([[185]])
# tensor([[ 42, 117, 118,   3, 119,  94, 120]]) tensor([[121]])
# tensor([[ 1,  2,  3,  4,  5, 99]]) tensor([[100]])
# tensor([[  1,   2,   3, 122, 123,  19,   3,  45]]) tensor([[124]])

# %%
import torch.nn as nn

# %%
class SimpleRNN(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim=50)
        self.rnn = nn.RNN(input_size=50, hidden_size=64, batch_first=True)
        self.fc = nn.Linear(64, vocab_size)

    def forward(self, question):
        embedded = self.embedding(question)
        output, hidden = self.rnn(embedded)
        logits = self.fc(hidden.squeeze(0))
        return logits

# %%
learning_rate = 0.001
epochs = 20

# %%
model = SimpleRNN(len(vocab))

# %%
criteria = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), learning_rate)

# %%
#Training Loop

for epoch in range(epochs):
  total_loss = 0

  for question,answer in dataloader:
    optimizer.zero_grad()

    #forward pass

    output = model(question)

    #loss calculation

    loss = criteria(output,answer[0])

    #gradient calculation

    loss.backward()

    #update
    optimizer.step()

    total_loss = total_loss + loss.item()

    print(f"Epoch{epoch+1}, Loss :{total_loss:4f}")
# Out:
# Epoch1, Loss :5.977479
# Epoch1, Loss :11.619404
# Epoch1, Loss :17.565052
# Epoch1, Loss :23.594137
# Epoch1, Loss :29.485584
# Epoch1, Loss :35.171918
# Epoch1, Loss :41.446091
# Epoch1, Loss :46.997931
# Epoch1, Loss :52.973187
# Epoch1, Loss :59.431196
# Epoch1, Loss :65.387921
# Epoch1, Loss :71.789455
# Epoch1, Loss :77.926933
# Epoch1, Loss :83.292551
# Epoch1, Loss :89.204816
# Epoch1, Loss :95.335165
# Epoch1, Loss :101.203071
# Epoch1, Loss :107.112060
# Epoch1, Loss :113.013514
# Epoch1, Loss :118.752610
# Epoch1, Loss :124.161299
# Epoch1, Loss :130.021074
# Epoch1, Loss :135.543647
# Epoch1, Loss :141.026884
# Epoch1, Loss :147.173638
# Epoch1, Loss :153.024897
# Epoch1, Loss :159.093737
# Epoch1, Loss :165.245022
# Epoch1, Loss :170.824929
# Epoch1, Loss :176.711901
# Epoch1, Loss :183.164813
# Epoch1, Loss :188.923104
# Epoch1, Loss :194.626947
# Epoch1, Loss :200.896986
# Epoch1, Loss :206.568041
# Epoch1, Loss :212.887962
# Epoch1, Loss :218.476767
# Epoch1, Loss :225.035460
# Epoch1, Loss :231.132951
# Epoch1, Loss :236.966425
# Epoch1, Loss :242.431569
# Epoch1, Loss :247.974590
# Epoch1, Loss :254.260629
# Epoch1, Loss :259.834153
# Epoch1, Loss :266.060341
# Epoch1, Loss :272.091910
# Epoch1, Loss :277.542899
# Epoch1, Loss :283.274837
# Epoch1, Loss :289.122084
# Epoch1, Loss :295.314169
# Epoch1, Loss :301.325356
# Epoch1, Loss :307.365325
# Epoch1, Loss :313.044865
# Epoch1, Loss :318.969002
# Epoch1, Loss :324.821916
# Epoch1, Loss :330.522491
# Epoch1, Loss :336.686602
# Epoch1, Loss :342.881699
# Epoch1, Loss :348.818570
# Epoch1, Loss :354.796512
# Epoch1, Loss :360.419458
# Epoch1, Loss :366.138031
# Epoch1, Loss :372.403086
# Epoch1, Loss :378.072136
# Epoch1, Loss :383.741987
# Epoch1, Loss :389.189687
# Epoch1, Loss :394.766357
# Epoch1, Loss :400.692888
# Epoch1, Loss :406.434136
# Epoch1, Loss :412.531643
# Epoch1, Loss :418.956416
# Epoch1, Loss :424.556908
# Epoch1, Loss :430.372453
# Epoch1, Loss :436.461498
# Epoch1, Loss :442.322631
# Epoch1, Loss :448.394098
# Epoch1, Loss :454.232486
# Epoch1, Loss :459.813976
# Epoch1, Loss :466.144897
# Epoch1, Loss :472.136093
# Epoch1, Loss :477.935410
# Epoch1, Loss :483.635150
# Epoch1, Loss :490.052016
# Epoch1, Loss :496.142421
# Epoch1, Loss :501.914690
# Epoch1, Loss :508.097350
# Epoch1, Loss :513.677979
# Epoch1, Loss :519.295719
# Epoch1, Loss :524.950887
# Epoch1, Loss :530.645918
# Epoch2, Loss :5.289424
# Epoch2, Loss :11.226250
# Epoch2, Loss :16.761961
# Epoch2, Loss :22.084746
# Epoch2, Loss :27.165252
# Epoch2, Loss :32.163185
# Epoch2, Loss :37.425325
# Epoch2, Loss :42.472123
# Epoch2, Loss :47.370679
# Epoch2, Loss :52.932309
# Epoch2, Loss :57.925411
# Epoch2, Loss :63.814219
# Epoch2, Loss :68.387312
# Epoch2, Loss :74.159282
# Epoch2, Loss :79.511614
# Epoch2, Loss :85.072012
# Epoch2, Loss :90.174131
# Epoch2, Loss :94.842514
# Epoch2, Loss :99.610463
# Epoch2, Loss :105.177478
# Epoch2, Loss :110.700236
# Epoch2, Loss :116.180582
# Epoch2, Loss :121.208458
# Epoch2, Loss :126.119344
# Epoch2, Loss :131.307715
# Epoch2, Loss :136.651033
# Epoch2, Loss :141.551921
# Epoch2, Loss :146.851358
# Epoch2, Loss :151.952101
# Epoch2, Loss :157.319886
# Epoch2, Loss :162.508242
# Epoch2, Loss :167.752876
# Epoch2, Loss :172.923837
# Epoch2, Loss :178.340699
# Epoch2, Loss :183.192797
# Epoch2, Loss :188.319887
# Epoch2, Loss :193.920937
# Epoch2, Loss :198.809840
# Epoch2, Loss :204.473897
# Epoch2, Loss :209.526004
# Epoch2, Loss :215.141865
# Epoch2, Loss :220.133753
# Epoch2, Loss :225.276146
# Epoch2, Loss :229.980263
# Epoch2, Loss :235.166380
# Epoch2, Loss :240.625260
# Epoch2, Loss :245.576721
# Epoch2, Loss :251.186725
# Epoch2, Loss :256.614547
# Epoch2, Loss :261.121504
# Epoch2, Loss :266.496884
# Epoch2, Loss :271.448186
# Epoch2, Loss :276.649302
# Epoch2, Loss :282.068925
# Epoch2, Loss :286.932146
# Epoch2, Loss :292.507018
# Epoch2, Loss :297.441280
# Epoch2, Loss :302.527278
# Epoch2, Loss :307.872527
# Epoch2, Loss :312.741004
# Epoch2, Loss :318.456564
# Epoch2, Loss :323.375113
# Epoch2, Loss :328.569775
# Epoch2, Loss :333.561184
# Epoch2, Loss :338.621741
# Epoch2, Loss :343.832697
# Epoch2, Loss :348.768041
# Epoch2, Loss :354.236687
# Epoch2, Loss :359.350477
# Epoch2, Loss :364.225915
# Epoch2, Loss :369.272869
# Epoch2, Loss :374.985791
# Epoch2, Loss :379.801698
# Epoch2, Loss :384.485312
# Epoch2, Loss :389.337160
# Epoch2, Loss :393.905177
# Epoch2, Loss :398.728413
# Epoch2, Loss :403.917782
# Epoch2, Loss :409.173594
# Epoch2, Loss :414.508023
# Epoch2, Loss :419.511877
# Epoch2, Loss :424.338348
# Epoch2, Loss :429.517174
# Epoch2, Loss :434.174037
# Epoch2, Loss :438.789520
# Epoch2, Loss :443.870506
# Epoch2, Loss :448.496236
# Epoch2, Loss :453.464951
# Epoch2, Loss :458.271251
# Epoch2, Loss :462.981467
# Epoch3, Loss :4.365772
# Epoch3, Loss :8.975435
# Epoch3, Loss :13.039256
# Epoch3, Loss :17.345595
# Epoch3, Loss :21.550086
# Epoch3, Loss :26.184949
# Epoch3, Loss :30.209239
# Epoch3, Loss :34.503515
# Epoch3, Loss :38.413525
# Epoch3, Loss :43.601761
# Epoch3, Loss :48.098079
# Epoch3, Loss :52.440481
# Epoch3, Loss :56.871953
# Epoch3, Loss :61.171801
# Epoch3, Loss :65.321007
# Epoch3, Loss :69.675161
# Epoch3, Loss :74.515066
# Epoch3, Loss :79.138180
# Epoch3, Loss :83.391764
# Epoch3, Loss :88.096713
# Epoch3, Loss :91.804796
# Epoch3, Loss :96.130196
# Epoch3, Loss :100.113249
# Epoch3, Loss :104.092767
# Epoch3, Loss :107.923486
# Epoch3, Loss :111.729601
# Epoch3, Loss :116.390670
# Epoch3, Loss :120.627581
# Epoch3, Loss :125.286741
# Epoch3, Loss :129.401635
# Epoch3, Loss :133.268146
# Epoch3, Loss :137.383281
# Epoch3, Loss :141.710596
# Epoch3, Loss :145.500125
# Epoch3, Loss :150.161913
# Epoch3, Loss :154.684976
# Epoch3, Loss :158.513925
# Epoch3, Loss :163.449055
# Epoch3, Loss :167.955729
# Epoch3, Loss :172.626981
# Epoch3, Loss :176.556016
# Epoch3, Loss :181.111339
# Epoch3, Loss :186.042344
# Epoch3, Loss :189.931252
# Epoch3, Loss :194.355363
# Epoch3, Loss :197.467561
# Epoch3, Loss :202.177915
# Epoch3, Loss :206.657641
# Epoch3, Loss :210.863897
# Epoch3, Loss :215.037371
# Epoch3, Loss :219.166080
# Epoch3, Loss :223.029288
# Epoch3, Loss :227.187701
# Epoch3, Loss :231.587198
# Epoch3, Loss :236.222089
# Epoch3, Loss :239.938734
# Epoch3, Loss :243.655839
# Epoch3, Loss :247.628667
# Epoch3, Loss :252.228964
# Epoch3, Loss :257.129786
# Epoch3, Loss :261.560415
# Epoch3, Loss :266.200753
# Epoch3, Loss :270.345785
# Epoch3, Loss :274.040987
# Epoch3, Loss :278.455413
# Epoch3, Loss :282.885069
# Epoch3, Loss :286.921214
# Epoch3, Loss :290.766879
# Epoch3, Loss :295.151915
# Epoch3, Loss :299.396437
# Epoch3, Loss :303.438921
# Epoch3, Loss :307.588570
# Epoch3, Loss :311.996988
# Epoch3, Loss :315.774059
# Epoch3, Loss :320.097831
# Epoch3, Loss :324.154646
# Epoch3, Loss :328.369061
# Epoch3, Loss :333.017290
# Epoch3, Loss :337.194755
# Epoch3, Loss :340.655575
# Epoch3, Loss :345.549755
# Epoch3, Loss :349.792319
# Epoch3, Loss :353.833300
# Epoch3, Loss :358.142296
# Epoch3, Loss :362.832014
# Epoch3, Loss :367.314500
# Epoch3, Loss :371.599320
# Epoch3, Loss :375.667155
# Epoch3, Loss :380.072925
# Epoch3, Loss :383.878453
# Epoch4, Loss :3.027206
# Epoch4, Loss :6.373937
# Epoch4, Loss :10.158213
# Epoch4, Loss :13.880271
# Epoch4, Loss :17.515897
# Epoch4, Loss :21.805212
# Epoch4, Loss :25.323613
# Epoch4, Loss :29.530260
# Epoch4, Loss :32.965159
# Epoch4, Loss :36.624557
# Epoch4, Loss :40.347184
# Epoch4, Loss :44.266043
# Epoch4, Loss :47.755619
# Epoch4, Loss :51.368278
# Epoch4, Loss :54.662863
# Epoch4, Loss :58.537966
# Epoch4, Loss :62.852020
# Epoch4, Loss :66.389025
# Epoch4, Loss :69.869816
# Epoch4, Loss :73.340797
# Epoch4, Loss :76.804270
# Epoch4, Loss :80.383964
# Epoch4, Loss :83.697015
# Epoch4, Loss :86.889468
# Epoch4, Loss :90.374800
# Epoch4, Loss :94.251023
# Epoch4, Loss :97.750578
# Epoch4, Loss :100.947741
# Epoch4, Loss :104.145575
# Epoch4, Loss :107.432268
# Epoch4, Loss :110.535249
# Epoch4, Loss :113.731333
# Epoch4, Loss :117.333839
# Epoch4, Loss :120.345859
# Epoch4, Loss :123.377272
# Epoch4, Loss :126.828070
# Epoch4, Loss :130.723158
# Epoch4, Loss :133.977045
# Epoch4, Loss :137.880282
# Epoch4, Loss :141.943246
# Epoch4, Loss :145.460197
# Epoch4, Loss :148.563933
# Epoch4, Loss :151.932234
# Epoch4, Loss :155.570885
# Epoch4, Loss :159.372150
# Epoch4, Loss :162.849442
# Epoch4, Loss :165.879316
# Epoch4, Loss :169.209478
# Epoch4, Loss :172.795515
# Epoch4, Loss :176.693410
# Epoch4, Loss :180.869384
# Epoch4, Loss :184.734441
# Epoch4, Loss :188.704740
# Epoch4, Loss :191.987235
# Epoch4, Loss :195.517740
# Epoch4, Loss :199.477950
# Epoch4, Loss :203.119983
# Epoch4, Loss :207.173122
# Epoch4, Loss :210.834413
# Epoch4, Loss :214.003770
# Epoch4, Loss :217.696395
# Epoch4, Loss :220.766527
# Epoch4, Loss :224.305485
# Epoch4, Loss :227.767429
# Epoch4, Loss :231.275937
# Epoch4, Loss :234.882940
# Epoch4, Loss :238.081434
# Epoch4, Loss :241.890284
# Epoch4, Loss :245.069555
# Epoch4, Loss :248.890970
# Epoch4, Loss :252.688752
# Epoch4, Loss :256.607202
# Epoch4, Loss :259.955675
# Epoch4, Loss :264.309359
# Epoch4, Loss :267.661547
# Epoch4, Loss :270.240048
# Epoch4, Loss :273.908381
# Epoch4, Loss :276.935573
# Epoch4, Loss :280.904766
# Epoch4, Loss :284.767699
# Epoch4, Loss :288.322923
# Epoch4, Loss :291.267807
# Epoch4, Loss :295.390775
# Epoch4, Loss :299.246811
# Epoch4, Loss :303.020868
# Epoch4, Loss :306.172684
# Epoch4, Loss :310.437044
# Epoch4, Loss :314.784223
# Epoch4, Loss :318.723094
# Epoch4, Loss :322.146211
# Epoch5, Loss :2.727327
# Epoch5, Loss :5.527267
# Epoch5, Loss :8.014523
# Epoch5, Loss :11.174037
# Epoch5, Loss :14.028007
# Epoch5, Loss :16.983490
# Epoch5, Loss :20.298029
# Epoch5, Loss :23.596496
# Epoch5, Loss :25.982345
# Epoch5, Loss :28.868848
# Epoch5, Loss :32.538538
# Epoch5, Loss :35.175555
# Epoch5, Loss :38.088262
# Epoch5, Loss :41.724745
# Epoch5, Loss :45.102212
# Epoch5, Loss :48.577135
# Epoch5, Loss :50.938739
# Epoch5, Loss :54.691578
# Epoch5, Loss :57.578918
# Epoch5, Loss :61.008135
# Epoch5, Loss :63.486542
# Epoch5, Loss :66.595724
# Epoch5, Loss :69.098787
# Epoch5, Loss :72.337401
# Epoch5, Loss :75.142557
# Epoch5, Loss :78.616659
# Epoch5, Loss :81.564871
# Epoch5, Loss :84.240799
# Epoch5, Loss :87.403526
# Epoch5, Loss :89.555962
# Epoch5, Loss :91.834665
# Epoch5, Loss :94.228089
# Epoch5, Loss :97.265133
# Epoch5, Loss :99.991634
# Epoch5, Loss :103.260821
# Epoch5, Loss :106.212599
# Epoch5, Loss :109.348520
# Epoch5, Loss :112.265950
# Epoch5, Loss :115.903277
# Epoch5, Loss :119.012790
# Epoch5, Loss :121.703729
# Epoch5, Loss :124.796425
# Epoch5, Loss :127.384267
# Epoch5, Loss :129.914140
# Epoch5, Loss :133.155722
# Epoch5, Loss :136.484331
# Epoch5, Loss :139.852469
# Epoch5, Loss :142.728938
# Epoch5, Loss :145.696453
# Epoch5, Loss :149.323758
# Epoch5, Loss :152.301123
# Epoch5, Loss :155.685231
# Epoch5, Loss :159.046129
# Epoch5, Loss :162.772793
# Epoch5, Loss :166.148573
# Epoch5, Loss :169.268880
# Epoch5, Loss :172.372736
# Epoch5, Loss :176.167540
# Epoch5, Loss :179.214331
# Epoch5, Loss :181.871338
# Epoch5, Loss :185.321592
# Epoch5, Loss :188.013205
# Epoch5, Loss :191.025101
# Epoch5, Loss :193.790765
# Epoch5, Loss :196.794042
# Epoch5, Loss :199.571686
# Epoch5, Loss :202.870166
# Epoch5, Loss :206.284499
# Epoch5, Loss :209.191345
# Epoch5, Loss :212.651446
# Epoch5, Loss :215.595948
# Epoch5, Loss :218.386081
# Epoch5, Loss :221.039649
# Epoch5, Loss :224.278741
# Epoch5, Loss :227.548238
# Epoch5, Loss :231.186214
# Epoch5, Loss :233.866205
# Epoch5, Loss :237.095475
# Epoch5, Loss :240.426383
# Epoch5, Loss :243.021190
# Epoch5, Loss :246.123071
# Epoch5, Loss :248.991107
# Epoch5, Loss :251.796504
# Epoch5, Loss :254.720157
# Epoch5, Loss :258.008592
# Epoch5, Loss :261.259916
# Epoch5, Loss :263.489685
# Epoch5, Loss :265.892491
# Epoch5, Loss :268.395591
# Epoch5, Loss :271.330336
# Epoch6, Loss :2.153418
# Epoch6, Loss :4.931667
# Epoch6, Loss :7.787246
# Epoch6, Loss :10.954219
# Epoch6, Loss :14.014995
# Epoch6, Loss :16.112479
# Epoch6, Loss :18.441161
# Epoch6, Loss :21.066776
# Epoch6, Loss :22.848564
# Epoch6, Loss :25.245814
# Epoch6, Loss :27.319679
# Epoch6, Loss :30.018736
# Epoch6, Loss :32.116033
# Epoch6, Loss :34.605307
# Epoch6, Loss :36.842339
# Epoch6, Loss :39.201432
# Epoch6, Loss :42.291245
# Epoch6, Loss :45.064266
# Epoch6, Loss :47.135667
# Epoch6, Loss :48.834277
# Epoch6, Loss :51.656266
# Epoch6, Loss :54.496065
# Epoch6, Loss :57.181563
# Epoch6, Loss :59.671413
# Epoch6, Loss :62.159301
# Epoch6, Loss :64.653769
# Epoch6, Loss :66.906873
# Epoch6, Loss :68.983698
# Epoch6, Loss :70.872657
# Epoch6, Loss :73.296807
# Epoch6, Loss :75.745170
# Epoch6, Loss :78.985872
# Epoch6, Loss :80.868066
# Epoch6, Loss :83.341377
# Epoch6, Loss :85.897792
# Epoch6, Loss :87.926698
# Epoch6, Loss :90.880553
# Epoch6, Loss :93.541570
# Epoch6, Loss :96.456569
# Epoch6, Loss :98.332995
# Epoch6, Loss :100.070590
# Epoch6, Loss :102.843778
# Epoch6, Loss :105.180077
# Epoch6, Loss :108.391505
# Epoch6, Loss :110.586773
# Epoch6, Loss :113.195517
# Epoch6, Loss :115.936046
# Epoch6, Loss :118.728046
# Epoch6, Loss :121.695867
# Epoch6, Loss :124.397393
# Epoch6, Loss :126.502156
# Epoch6, Loss :129.382287
# Epoch6, Loss :131.586706
# Epoch6, Loss :133.456971
# Epoch6, Loss :136.085050
# Epoch6, Loss :138.640548
# Epoch6, Loss :141.137725
# Epoch6, Loss :143.004040
# Epoch6, Loss :145.129688
# Epoch6, Loss :147.931456
# Epoch6, Loss :149.612660
# Epoch6, Loss :151.891925
# Epoch6, Loss :154.566567
# Epoch6, Loss :157.563633
# Epoch6, Loss :159.994743
# Epoch6, Loss :162.531976
# Epoch6, Loss :164.808924
# Epoch6, Loss :167.514460
# Epoch6, Loss :170.561082
# Epoch6, Loss :173.044619
# Epoch6, Loss :174.726852
# Epoch6, Loss :176.648141
# Epoch6, Loss :179.226508
# Epoch6, Loss :181.902841
# Epoch6, Loss :185.283445
# Epoch6, Loss :188.671997
# Epoch6, Loss :190.917858
# Epoch6, Loss :193.694882
# Epoch6, Loss :195.882552
# Epoch6, Loss :198.193147
# Epoch6, Loss :200.339372
# Epoch6, Loss :202.550483
# Epoch6, Loss :205.530713
# Epoch6, Loss :208.027682
# Epoch6, Loss :210.878519
# Epoch6, Loss :213.463067
# Epoch6, Loss :215.756308
# Epoch6, Loss :218.993539
# Epoch6, Loss :221.088400
# Epoch6, Loss :223.123916
# Epoch7, Loss :1.485005
# Epoch7, Loss :3.700182
# Epoch7, Loss :6.525772
# Epoch7, Loss :9.238987
# Epoch7, Loss :11.652065
# Epoch7, Loss :12.816747
# Epoch7, Loss :14.931297
# Epoch7, Loss :16.937569
# Epoch7, Loss :18.392306
# Epoch7, Loss :20.192044
# Epoch7, Loss :22.183285
# Epoch7, Loss :24.014353
# Epoch7, Loss :26.417276
# Epoch7, Loss :28.466718
# Epoch7, Loss :30.862194
# Epoch7, Loss :32.890626
# Epoch7, Loss :35.240173
# Epoch7, Loss :37.194206
# Epoch7, Loss :39.224975
# Epoch7, Loss :40.654456
# Epoch7, Loss :42.530803
# Epoch7, Loss :43.900093
# Epoch7, Loss :46.020038
# Epoch7, Loss :47.680736
# Epoch7, Loss :49.227735
# Epoch7, Loss :51.181648
# Epoch7, Loss :52.674272
# Epoch7, Loss :54.994476
# Epoch7, Loss :57.118094
# Epoch7, Loss :58.347208
# Epoch7, Loss :59.898993
# Epoch7, Loss :62.583040
# Epoch7, Loss :64.719071
# Epoch7, Loss :67.203272
# Epoch7, Loss :68.960671
# Epoch7, Loss :70.558217
# Epoch7, Loss :71.721473
# Epoch7, Loss :73.453712
# Epoch7, Loss :75.041267
# Epoch7, Loss :76.677421
# Epoch7, Loss :78.638436
# Epoch7, Loss :81.036278
# Epoch7, Loss :82.745118
# Epoch7, Loss :84.781672
# Epoch7, Loss :87.056092
# Epoch7, Loss :89.276629
# Epoch7, Loss :92.140937
# Epoch7, Loss :94.278200
# Epoch7, Loss :96.459203
# Epoch7, Loss :98.494705
# Epoch7, Loss :100.514283
# Epoch7, Loss :102.435620
# Epoch7, Loss :104.656078
# Epoch7, Loss :106.645787
# Epoch7, Loss :108.149955
# Epoch7, Loss :110.656685
# Epoch7, Loss :112.923055
# Epoch7, Loss :114.926042
# Epoch7, Loss :116.448400
# Epoch7, Loss :118.007491
# Epoch7, Loss :120.434251
# Epoch7, Loss :122.671179
# Epoch7, Loss :124.092444
# Epoch7, Loss :125.690976
# Epoch7, Loss :127.544099
# Epoch7, Loss :129.521461
# Epoch7, Loss :132.512463
# Epoch7, Loss :134.285458
# Epoch7, Loss :136.485628
# Epoch7, Loss :137.607396
# Epoch7, Loss :139.968578
# Epoch7, Loss :141.902744
# Epoch7, Loss :144.346354
# Epoch7, Loss :145.967875
# Epoch7, Loss :148.326718
# Epoch7, Loss :149.983530
# Epoch7, Loss :152.504789
# Epoch7, Loss :154.986470
# Epoch7, Loss :157.460051
# Epoch7, Loss :158.918722
# Epoch7, Loss :160.734879
# Epoch7, Loss :162.459629
# Epoch7, Loss :164.625045
# Epoch7, Loss :167.355613
# Epoch7, Loss :168.973035
# Epoch7, Loss :170.358857
# Epoch7, Loss :172.688931
# Epoch7, Loss :174.065460
# Epoch7, Loss :176.913253
# Epoch7, Loss :178.645442
# Epoch8, Loss :1.572588
# Epoch8, Loss :3.508032
# Epoch8, Loss :5.394996
# Epoch8, Loss :6.309024
# Epoch8, Loss :7.738257
# Epoch8, Loss :9.158346
# Epoch8, Loss :11.105299
# Epoch8, Loss :12.448508
# Epoch8, Loss :14.018061
# Epoch8, Loss :15.059894
# Epoch8, Loss :16.446850
# Epoch8, Loss :18.791889
# Epoch8, Loss :19.801582
# Epoch8, Loss :21.418358
# Epoch8, Loss :22.668410
# Epoch8, Loss :24.515681
# Epoch8, Loss :26.529875
# Epoch8, Loss :28.466602
# Epoch8, Loss :30.698649
# Epoch8, Loss :33.024006
# Epoch8, Loss :34.705076
# Epoch8, Loss :35.882625
# Epoch8, Loss :37.606714
# Epoch8, Loss :39.357188
# Epoch8, Loss :40.851553
# Epoch8, Loss :42.926961
# Epoch8, Loss :44.801994
# Epoch8, Loss :47.105725
# Epoch8, Loss :48.509249
# Epoch8, Loss :49.460447
# Epoch8, Loss :50.637368
# Epoch8, Loss :51.744810
# Epoch8, Loss :53.037633
# Epoch8, Loss :54.244039
# Epoch8, Loss :56.680281
# Epoch8, Loss :58.118905
# Epoch8, Loss :60.051139
# Epoch8, Loss :61.772803
# Epoch8, Loss :63.360248
# Epoch8, Loss :65.259096
# Epoch8, Loss :66.705167
# Epoch8, Loss :68.407179
# Epoch8, Loss :70.218510
# Epoch8, Loss :71.383838
# Epoch8, Loss :72.563867
# Epoch8, Loss :73.813859
# Epoch8, Loss :75.938946
# Epoch8, Loss :77.649856
# Epoch8, Loss :79.280442
# Epoch8, Loss :80.172866
# Epoch8, Loss :81.974825
# Epoch8, Loss :83.283267
# Epoch8, Loss :84.255227
# Epoch8, Loss :85.890844
# Epoch8, Loss :87.772776
# Epoch8, Loss :88.971734
# Epoch8, Loss :90.788989
# Epoch8, Loss :91.928768
# Epoch8, Loss :93.525069
# Epoch8, Loss :95.371275
# Epoch8, Loss :96.419801
# Epoch8, Loss :97.652075
# Epoch8, Loss :99.225123
# Epoch8, Loss :100.237341
# Epoch8, Loss :101.779530
# Epoch8, Loss :102.985299
# Epoch8, Loss :104.624346
# Epoch8, Loss :105.724005
# Epoch8, Loss :108.388437
# Epoch8, Loss :110.344997
# Epoch8, Loss :111.817108
# Epoch8, Loss :113.603258
# Epoch8, Loss :114.821963
# Epoch8, Loss :116.532777
# Epoch8, Loss :118.222313
# Epoch8, Loss :119.478629
# Epoch8, Loss :120.388858
# Epoch8, Loss :121.260282
# Epoch8, Loss :122.299672
# Epoch8, Loss :123.741445
# Epoch8, Loss :124.784925
# Epoch8, Loss :126.135117
# Epoch8, Loss :127.224816
# Epoch8, Loss :128.839694
# Epoch8, Loss :129.871203
# Epoch8, Loss :131.273299
# Epoch8, Loss :133.201610
# Epoch8, Loss :134.737973
# Epoch8, Loss :137.007479
# Epoch8, Loss :139.564989
# Epoch9, Loss :2.147541
# Epoch9, Loss :2.947147
# Epoch9, Loss :3.781406
# Epoch9, Loss :4.920584
# Epoch9, Loss :6.543216
# Epoch9, Loss :7.193506
# Epoch9, Loss :8.970289
# Epoch9, Loss :9.843258
# Epoch9, Loss :10.514878
# Epoch9, Loss :11.357112
# Epoch9, Loss :12.795107
# Epoch9, Loss :14.110313
# Epoch9, Loss :15.253408
# Epoch9, Loss :16.525456
# Epoch9, Loss :17.774257
# Epoch9, Loss :18.558728
# Epoch9, Loss :19.564636
# Epoch9, Loss :21.170094
# Epoch9, Loss :22.785886
# Epoch9, Loss :23.695774
# Epoch9, Loss :25.153464
# Epoch9, Loss :25.844751
# Epoch9, Loss :27.690478
# Epoch9, Loss :29.163227
# Epoch9, Loss :30.607204
# Epoch9, Loss :32.188817
# Epoch9, Loss :33.028364
# Epoch9, Loss :34.228254
# Epoch9, Loss :35.978428
# Epoch9, Loss :37.148092
# Epoch9, Loss :38.025993
# Epoch9, Loss :38.953748
# Epoch9, Loss :40.153632
# Epoch9, Loss :41.522729
# Epoch9, Loss :42.258555
# Epoch9, Loss :43.050515
# Epoch9, Loss :44.256070
# Epoch9, Loss :46.149510
# Epoch9, Loss :46.756095
# Epoch9, Loss :48.139337
# Epoch9, Loss :48.814817
# Epoch9, Loss :49.860203
# Epoch9, Loss :52.160860
# Epoch9, Loss :53.993083
# Epoch9, Loss :55.146854
# Epoch9, Loss :56.153901
# Epoch9, Loss :58.233965
# Epoch9, Loss :59.854531
# Epoch9, Loss :61.015294
# Epoch9, Loss :62.246880
# Epoch9, Loss :63.780176
# Epoch9, Loss :64.794720
# Epoch9, Loss :65.781061
# Epoch9, Loss :66.585634
# Epoch9, Loss :67.416586
# Epoch9, Loss :68.585188
# Epoch9, Loss :69.613459
# Epoch9, Loss :71.006317
# Epoch9, Loss :71.595730
# Epoch9, Loss :72.513084
# Epoch9, Loss :73.268415
# Epoch9, Loss :74.369923
# Epoch9, Loss :75.542605
# Epoch9, Loss :76.163493
# Epoch9, Loss :76.975867
# Epoch9, Loss :77.723380
# Epoch9, Loss :78.744052
# Epoch9, Loss :79.451337
# Epoch9, Loss :80.047796
# Epoch9, Loss :81.126168
# Epoch9, Loss :82.677982
# Epoch9, Loss :83.353785
# Epoch9, Loss :84.367483
# Epoch9, Loss :85.693660
# Epoch9, Loss :86.782217
# Epoch9, Loss :87.935612
# Epoch9, Loss :88.805218
# Epoch9, Loss :90.057211
# Epoch9, Loss :91.258045
# Epoch9, Loss :92.072180
# Epoch9, Loss :93.784728
# Epoch9, Loss :95.933556
# Epoch9, Loss :97.363883
# Epoch9, Loss :98.905655
# Epoch9, Loss :99.910717
# Epoch9, Loss :101.272391
# Epoch9, Loss :103.179311
# Epoch9, Loss :104.521572
# Epoch9, Loss :105.948198
# Epoch9, Loss :107.476561
# Epoch10, Loss :0.451523
# Epoch10, Loss :1.487390
# Epoch10, Loss :2.188069
# Epoch10, Loss :3.899420
# Epoch10, Loss :4.544679
# Epoch10, Loss :5.296715
# Epoch10, Loss :5.949634
# Epoch10, Loss :6.349158
# Epoch10, Loss :7.088039
# Epoch10, Loss :7.590389
# Epoch10, Loss :8.311965
# Epoch10, Loss :9.716534
# Epoch10, Loss :10.629884
# Epoch10, Loss :11.125517
# Epoch10, Loss :12.278401
# Epoch10, Loss :13.906203
# Epoch10, Loss :14.902294
# Epoch10, Loss :15.444921
# Epoch10, Loss :16.363312
# Epoch10, Loss :16.932914
# Epoch10, Loss :17.715423
# Epoch10, Loss :18.548066
# Epoch10, Loss :19.364201
# Epoch10, Loss :20.486762
# Epoch10, Loss :21.406827
# Epoch10, Loss :22.792288
# Epoch10, Loss :23.537402
# Epoch10, Loss :24.844129
# Epoch10, Loss :26.260097
# Epoch10, Loss :27.007866
# Epoch10, Loss :28.336850
# Epoch10, Loss :29.111261
# Epoch10, Loss :29.963052
# Epoch10, Loss :31.037026
# Epoch10, Loss :32.381735
# Epoch10, Loss :34.226630
# Epoch10, Loss :35.518906
# Epoch10, Loss :37.445525
# Epoch10, Loss :38.918132
# Epoch10, Loss :39.999430
# Epoch10, Loss :40.861401
# Epoch10, Loss :41.797264
# Epoch10, Loss :42.882443
# Epoch10, Loss :43.420678
# Epoch10, Loss :44.219394
# Epoch10, Loss :44.732037
# Epoch10, Loss :45.626478
# Epoch10, Loss :46.758442
# Epoch10, Loss :47.861059
# Epoch10, Loss :48.429283
# Epoch10, Loss :49.163327
# Epoch10, Loss :49.771616
# Epoch10, Loss :50.501289
# Epoch10, Loss :51.035786
# Epoch10, Loss :51.997978
# Epoch10, Loss :52.525338
# Epoch10, Loss :53.824891
# Epoch10, Loss :54.617950
# Epoch10, Loss :55.277114
# Epoch10, Loss :56.122794
# Epoch10, Loss :56.731966
# Epoch10, Loss :57.738801
# Epoch10, Loss :58.923503
# Epoch10, Loss :60.577162
# Epoch10, Loss :61.120433
# Epoch10, Loss :61.806118
# Epoch10, Loss :62.793961
# Epoch10, Loss :63.317840
# Epoch10, Loss :64.095547
# Epoch10, Loss :64.934103
# Epoch10, Loss :65.510329
# Epoch10, Loss :66.682987
# Epoch10, Loss :67.253296
# Epoch10, Loss :67.975920
# Epoch10, Loss :68.453659
# Epoch10, Loss :69.525483
# Epoch10, Loss :70.366980
# Epoch10, Loss :71.509902
# Epoch10, Loss :72.719997
# Epoch10, Loss :73.401355
# Epoch10, Loss :73.861053
# Epoch10, Loss :74.828415
# Epoch10, Loss :75.540490
# Epoch10, Loss :77.180222
# Epoch10, Loss :78.501337
# Epoch10, Loss :79.256691
# Epoch10, Loss :79.961118
# Epoch10, Loss :81.001588
# Epoch10, Loss :81.578942
# Epoch10, Loss :82.382215
# Epoch11, Loss :1.576235
# Epoch11, Loss :2.143991
# Epoch11, Loss :3.183642
# Epoch11, Loss :3.905704
# Epoch11, Loss :4.260764
# Epoch11, Loss :4.640376
# Epoch11, Loss :5.231477
# Epoch11, Loss :5.655959
# Epoch11, Loss :6.322638
# Epoch11, Loss :6.745824
# Epoch11, Loss :7.342112
# Epoch11, Loss :8.929194
# Epoch11, Loss :9.403718
# Epoch11, Loss :10.081750
# Epoch11, Loss :10.910864
# Epoch11, Loss :11.432916
# Epoch11, Loss :12.328249
# Epoch11, Loss :13.395411
# Epoch11, Loss :13.843091
# Epoch11, Loss :14.503941
# Epoch11, Loss :14.950443
# Epoch11, Loss :15.562185
# Epoch11, Loss :16.126215
# Epoch11, Loss :16.856151
# Epoch11, Loss :18.328218
# Epoch11, Loss :18.694068
# Epoch11, Loss :19.656263
# Epoch11, Loss :20.221350
# Epoch11, Loss :21.839760
# Epoch11, Loss :22.286842
# Epoch11, Loss :22.832324
# Epoch11, Loss :23.380253
# Epoch11, Loss :23.942688
# Epoch11, Loss :24.439330
# Epoch11, Loss :25.277867
# Epoch11, Loss :25.597003
# Epoch11, Loss :26.415735
# Epoch11, Loss :26.785726
# Epoch11, Loss :27.621310
# Epoch11, Loss :28.058741
# Epoch11, Loss :29.566178
# Epoch11, Loss :30.247872
# Epoch11, Loss :30.642417
# Epoch11, Loss :31.482510
# Epoch11, Loss :32.678539
# Epoch11, Loss :33.736124
# Epoch11, Loss :34.163827
# Epoch11, Loss :34.885096
# Epoch11, Loss :35.654704
# Epoch11, Loss :36.765958
# Epoch11, Loss :37.560527
# Epoch11, Loss :38.859718
# Epoch11, Loss :39.316733
# Epoch11, Loss :39.921675
# Epoch11, Loss :40.504717
# Epoch11, Loss :41.311920
# Epoch11, Loss :41.822566
# Epoch11, Loss :43.022522
# Epoch11, Loss :43.402322
# Epoch11, Loss :43.774471
# Epoch11, Loss :44.351847
# Epoch11, Loss :45.230523
# Epoch11, Loss :46.098282
# Epoch11, Loss :46.952910
# Epoch11, Loss :47.295553
# Epoch11, Loss :48.030671
# Epoch11, Loss :48.764837
# Epoch11, Loss :49.334508
# Epoch11, Loss :49.904494
# Epoch11, Loss :50.495451
# Epoch11, Loss :51.409629
# Epoch11, Loss :51.844311
# Epoch11, Loss :52.804047
# Epoch11, Loss :53.499790
# Epoch11, Loss :54.104369
# Epoch11, Loss :54.589711
# Epoch11, Loss :55.290930
# Epoch11, Loss :55.725512
# Epoch11, Loss :56.297890
# Epoch11, Loss :56.957043
# Epoch11, Loss :57.351046
# Epoch11, Loss :58.720072
# Epoch11, Loss :59.564763
# Epoch11, Loss :60.136992
# Epoch11, Loss :60.471680
# Epoch11, Loss :60.875314
# Epoch11, Loss :61.866142
# Epoch11, Loss :62.349627
# Epoch11, Loss :63.023322
# Epoch11, Loss :63.627109
# Epoch12, Loss :0.326673
# Epoch12, Loss :0.730790
# Epoch12, Loss :1.261521
# Epoch12, Loss :1.551175
# Epoch12, Loss :2.081833
# Epoch12, Loss :2.559310
# Epoch12, Loss :2.968477
# Epoch12, Loss :3.464139
# Epoch12, Loss :3.776503
# Epoch12, Loss :4.202234
# Epoch12, Loss :4.707126
# Epoch12, Loss :5.115057
# Epoch12, Loss :5.956595
# Epoch12, Loss :6.213427
# Epoch12, Loss :6.797026
# Epoch12, Loss :7.487579
# Epoch12, Loss :8.855971
# Epoch12, Loss :9.288759
# Epoch12, Loss :10.082636
# Epoch12, Loss :10.339326
# Epoch12, Loss :11.830863
# Epoch12, Loss :12.124960
# Epoch12, Loss :13.066284
# Epoch12, Loss :13.307792
# Epoch12, Loss :13.646484
# Epoch12, Loss :13.899709
# Epoch12, Loss :14.395437
# Epoch12, Loss :15.761133
# Epoch12, Loss :16.127931
# Epoch12, Loss :16.440530
# Epoch12, Loss :16.758946
# Epoch12, Loss :17.211772
# Epoch12, Loss :17.619804
# Epoch12, Loss :17.951836
# Epoch12, Loss :18.393184
# Epoch12, Loss :18.805567
# Epoch12, Loss :19.399143
# Epoch12, Loss :19.708788
# Epoch12, Loss :20.212219
# Epoch12, Loss :20.635409
# Epoch12, Loss :21.326012
# Epoch12, Loss :21.856447
# Epoch12, Loss :22.440311
# Epoch12, Loss :23.051346
# Epoch12, Loss :23.491607
# Epoch12, Loss :24.785471
# Epoch12, Loss :25.246498
# Epoch12, Loss :25.808943
# Epoch12, Loss :26.675188
# Epoch12, Loss :27.112012
# Epoch12, Loss :27.417131
# Epoch12, Loss :28.335914
# Epoch12, Loss :28.930961
# Epoch12, Loss :29.545567
# Epoch12, Loss :29.994150
# Epoch12, Loss :30.509383
# Epoch12, Loss :31.416242
# Epoch12, Loss :31.729795
# Epoch12, Loss :32.195785
# Epoch12, Loss :32.554427
# Epoch12, Loss :32.944508
# Epoch12, Loss :33.293525
# Epoch12, Loss :34.081970
# Epoch12, Loss :34.429901
# Epoch12, Loss :34.969482
# Epoch12, Loss :35.612202
# Epoch12, Loss :35.992261
# Epoch12, Loss :37.223077
# Epoch12, Loss :38.218934
# Epoch12, Loss :38.754530
# Epoch12, Loss :39.443622
# Epoch12, Loss :39.751026
# Epoch12, Loss :40.389173
# Epoch12, Loss :40.740383
# Epoch12, Loss :41.396707
# Epoch12, Loss :41.918976
# Epoch12, Loss :42.269295
# Epoch12, Loss :42.779954
# Epoch12, Loss :44.265892
# Epoch12, Loss :44.790036
# Epoch12, Loss :45.247716
# Epoch12, Loss :45.838488
# Epoch12, Loss :46.111805
# Epoch12, Loss :46.404763
# Epoch12, Loss :47.070718
# Epoch12, Loss :47.511653
# Epoch12, Loss :48.187904
# Epoch12, Loss :48.787135
# Epoch12, Loss :49.391319
# Epoch12, Loss :49.694848
# Epoch13, Loss :1.120409
# Epoch13, Loss :1.320531
# Epoch13, Loss :1.831621
# Epoch13, Loss :2.287124
# Epoch13, Loss :2.634918
# Epoch13, Loss :2.990043
# Epoch13, Loss :3.208617
# Epoch13, Loss :3.458823
# Epoch13, Loss :3.815207
# Epoch13, Loss :4.230679
# Epoch13, Loss :4.745588
# Epoch13, Loss :5.088732
# Epoch13, Loss :5.524599
# Epoch13, Loss :5.754937
# Epoch13, Loss :6.203408
# Epoch13, Loss :6.473103
# Epoch13, Loss :6.716469
# Epoch13, Loss :7.079763
# Epoch13, Loss :7.525422
# Epoch13, Loss :7.892572
# Epoch13, Loss :8.129252
# Epoch13, Loss :8.584846
# Epoch13, Loss :8.930640
# Epoch13, Loss :9.236511
# Epoch13, Loss :9.613163
# Epoch13, Loss :9.944904
# Epoch13, Loss :10.266970
# Epoch13, Loss :10.915219
# Epoch13, Loss :11.394220
# Epoch13, Loss :11.675774
# Epoch13, Loss :12.153655
# Epoch13, Loss :12.498622
# Epoch13, Loss :12.873219
# Epoch13, Loss :14.214695
# Epoch13, Loss :14.615862
# Epoch13, Loss :15.042098
# Epoch13, Loss :15.373238
# Epoch13, Loss :16.088754
# Epoch13, Loss :16.357954
# Epoch13, Loss :16.694755
# Epoch13, Loss :16.893470
# Epoch13, Loss :17.084642
# Epoch13, Loss :17.447305
# Epoch13, Loss :18.397331
# Epoch13, Loss :18.629909
# Epoch13, Loss :19.099549
# Epoch13, Loss :19.307767
# Epoch13, Loss :19.726153
# Epoch13, Loss :19.965553
# Epoch13, Loss :20.243345
# Epoch13, Loss :20.503188
# Epoch13, Loss :20.849961
# Epoch13, Loss :21.552412
# Epoch13, Loss :22.428376
# Epoch13, Loss :22.785513
# Epoch13, Loss :23.285859
# Epoch13, Loss :23.573528
# Epoch13, Loss :23.950317
# Epoch13, Loss :24.277325
# Epoch13, Loss :24.612042
# Epoch13, Loss :24.879150
# Epoch13, Loss :25.245093
# Epoch13, Loss :25.568327
# Epoch13, Loss :25.988387
# Epoch13, Loss :26.275996
# Epoch13, Loss :26.706268
# Epoch13, Loss :27.092991
# Epoch13, Loss :27.357469
# Epoch13, Loss :28.244488
# Epoch13, Loss :28.509742
# Epoch13, Loss :29.491506
# Epoch13, Loss :29.819127
# Epoch13, Loss :30.536351
# Epoch13, Loss :31.047886
# Epoch13, Loss :31.303871
# Epoch13, Loss :31.747638
# Epoch13, Loss :32.375616
# Epoch13, Loss :32.854262
# Epoch13, Loss :33.374392
# Epoch13, Loss :35.097478
# Epoch13, Loss :35.460356
# Epoch13, Loss :36.698482
# Epoch13, Loss :37.004076
# Epoch13, Loss :37.495131
# Epoch13, Loss :37.870310
# Epoch13, Loss :38.143503
# Epoch13, Loss :38.407724
# Epoch13, Loss :38.885894
# Epoch13, Loss :39.534689
# Epoch13, Loss :39.761421
# Epoch14, Loss :0.236649
# Epoch14, Loss :0.475923
# Epoch14, Loss :0.684791
# Epoch14, Loss :0.977310
# Epoch14, Loss :1.165874
# Epoch14, Loss :1.367443
# Epoch14, Loss :1.664425
# Epoch14, Loss :1.990485
# Epoch14, Loss :2.174582
# Epoch14, Loss :2.917813
# Epoch14, Loss :3.295927
# Epoch14, Loss :3.511090
# Epoch14, Loss :3.784721
# Epoch14, Loss :3.976648
# Epoch14, Loss :4.330935
# Epoch14, Loss :4.529757
# Epoch14, Loss :4.700153
# Epoch14, Loss :4.996107
# Epoch14, Loss :5.524581
# Epoch14, Loss :5.780386
# Epoch14, Loss :6.353325
# Epoch14, Loss :6.607519
# Epoch14, Loss :6.908837
# Epoch14, Loss :7.170018
# Epoch14, Loss :7.426969
# Epoch14, Loss :7.827325
# Epoch14, Loss :8.059082
# Epoch14, Loss :8.242662
# Epoch14, Loss :8.576479
# Epoch14, Loss :8.901753
# Epoch14, Loss :9.076152
# Epoch14, Loss :9.377173
# Epoch14, Loss :10.021930
# Epoch14, Loss :11.131125
# Epoch14, Loss :11.336019
# Epoch14, Loss :11.619738
# Epoch14, Loss :11.859810
# Epoch14, Loss :12.088007
# Epoch14, Loss :12.270926
# Epoch14, Loss :12.740561
# Epoch14, Loss :13.109833
# Epoch14, Loss :13.520074
# Epoch14, Loss :14.579924
# Epoch14, Loss :14.929624
# Epoch14, Loss :15.286182
# Epoch14, Loss :15.673623
# Epoch14, Loss :15.938938
# Epoch14, Loss :17.234631
# Epoch14, Loss :17.445044
# Epoch14, Loss :17.790442
# Epoch14, Loss :18.092084
# Epoch14, Loss :18.395093
# Epoch14, Loss :18.595483
# Epoch14, Loss :18.872379
# Epoch14, Loss :19.081410
# Epoch14, Loss :19.716199
# Epoch14, Loss :20.514620
# Epoch14, Loss :21.419029
# Epoch14, Loss :21.669912
# Epoch14, Loss :21.949394
# Epoch14, Loss :22.319941
# Epoch14, Loss :22.759518
# Epoch14, Loss :22.998775
# Epoch14, Loss :23.395495
# Epoch14, Loss :23.657982
# Epoch14, Loss :23.958857
# Epoch14, Loss :24.251019
# Epoch14, Loss :24.806255
# Epoch14, Loss :25.135190
# Epoch14, Loss :25.371371
# Epoch14, Loss :25.769073
# Epoch14, Loss :26.071951
# Epoch14, Loss :26.416594
# Epoch14, Loss :26.753318
# Epoch14, Loss :27.065979
# Epoch14, Loss :27.871372
# Epoch14, Loss :28.099688
# Epoch14, Loss :28.430849
# Epoch14, Loss :28.719069
# Epoch14, Loss :28.926429
# Epoch14, Loss :29.136720
# Epoch14, Loss :29.442117
# Epoch14, Loss :29.732761
# Epoch14, Loss :29.908323
# Epoch14, Loss :30.316436
# Epoch14, Loss :30.493939
# Epoch14, Loss :30.859390
# Epoch14, Loss :31.158873
# Epoch14, Loss :31.618718
# Epoch14, Loss :31.983459
# Epoch15, Loss :0.189842
# Epoch15, Loss :0.365347
# Epoch15, Loss :0.526509
# Epoch15, Loss :1.003428
# Epoch15, Loss :1.316178
# Epoch15, Loss :1.485555
# Epoch15, Loss :1.678831
# Epoch15, Loss :2.605052
# Epoch15, Loss :2.840458
# Epoch15, Loss :3.082059
# Epoch15, Loss :3.495615
# Epoch15, Loss :3.663324
# Epoch15, Loss :4.163824
# Epoch15, Loss :4.417889
# Epoch15, Loss :4.560165
# Epoch15, Loss :4.997928
# Epoch15, Loss :5.157096
# Epoch15, Loss :5.390872
# Epoch15, Loss :5.605064
# Epoch15, Loss :5.769534
# Epoch15, Loss :5.944907
# Epoch15, Loss :6.099608
# Epoch15, Loss :6.345730
# Epoch15, Loss :6.600143
# Epoch15, Loss :6.908629
# Epoch15, Loss :7.045458
# Epoch15, Loss :7.273496
# Epoch15, Loss :8.632716
# Epoch15, Loss :8.957300
# Epoch15, Loss :9.137716
# Epoch15, Loss :9.332011
# Epoch15, Loss :9.495005
# Epoch15, Loss :9.661109
# Epoch15, Loss :9.928849
# Epoch15, Loss :10.222630
# Epoch15, Loss :10.439735
# Epoch15, Loss :10.667747
# Epoch15, Loss :10.888221
# Epoch15, Loss :11.186651
# Epoch15, Loss :11.351439
# Epoch15, Loss :11.992269
# Epoch15, Loss :12.326592
# Epoch15, Loss :13.270882
# Epoch15, Loss :13.586811
# Epoch15, Loss :13.858684
# Epoch15, Loss :14.088899
# Epoch15, Loss :14.273990
# Epoch15, Loss :14.490410
# Epoch15, Loss :14.732305
# Epoch15, Loss :15.615517
# Epoch15, Loss :15.844112
# Epoch15, Loss :16.135141
# Epoch15, Loss :16.403345
# Epoch15, Loss :16.783442
# Epoch15, Loss :17.050887
# Epoch15, Loss :17.411236
# Epoch15, Loss :17.900609
# Epoch15, Loss :18.072567
# Epoch15, Loss :18.338749
# Epoch15, Loss :18.488104
# Epoch15, Loss :18.777023
# Epoch15, Loss :18.964792
# Epoch15, Loss :19.240281
# Epoch15, Loss :19.488026
# Epoch15, Loss :19.799726
# Epoch15, Loss :20.124681
# Epoch15, Loss :20.344293
# Epoch15, Loss :20.523141
# Epoch15, Loss :20.762251
# Epoch15, Loss :20.986507
# Epoch15, Loss :21.184157
# Epoch15, Loss :21.407272
# Epoch15, Loss :21.579510
# Epoch15, Loss :22.119478
# Epoch15, Loss :22.335233
# Epoch15, Loss :22.529340
# Epoch15, Loss :22.747142
# Epoch15, Loss :23.015427
# Epoch15, Loss :23.293500
# Epoch15, Loss :23.439995
# Epoch15, Loss :23.750370
# Epoch15, Loss :24.016198
# Epoch15, Loss :24.172708
# Epoch15, Loss :24.512491
# Epoch15, Loss :24.822701
# Epoch15, Loss :25.584849
# Epoch15, Loss :25.835140
# Epoch15, Loss :26.075536
# Epoch15, Loss :26.295446
# Epoch15, Loss :26.440448
# Epoch16, Loss :0.610281
# Epoch16, Loss :0.796761
# Epoch16, Loss :1.011520
# Epoch16, Loss :1.153417
# Epoch16, Loss :1.327452
# Epoch16, Loss :1.451307
# Epoch16, Loss :1.776970
# Epoch16, Loss :2.123139
# Epoch16, Loss :2.337543
# Epoch16, Loss :2.518804
# Epoch16, Loss :2.647606
# Epoch16, Loss :3.688917
# Epoch16, Loss :3.874116
# Epoch16, Loss :4.008257
# Epoch16, Loss :4.217548
# Epoch16, Loss :4.352829
# Epoch16, Loss :4.528914
# Epoch16, Loss :5.063797
# Epoch16, Loss :5.365894
# Epoch16, Loss :5.493013
# Epoch16, Loss :5.635191
# Epoch16, Loss :5.862847
# Epoch16, Loss :5.999167
# Epoch16, Loss :6.142684
# Epoch16, Loss :6.353644
# Epoch16, Loss :6.516307
# Epoch16, Loss :6.661294
# Epoch16, Loss :6.841117
# Epoch16, Loss :6.983104
# Epoch16, Loss :7.442249
# Epoch16, Loss :7.698611
# Epoch16, Loss :7.873481
# Epoch16, Loss :9.083450
# Epoch16, Loss :9.273285
# Epoch16, Loss :9.515053
# Epoch16, Loss :9.725488
# Epoch16, Loss :9.937048
# Epoch16, Loss :10.416452
# Epoch16, Loss :10.651944
# Epoch16, Loss :10.818726
# Epoch16, Loss :11.039903
# Epoch16, Loss :11.165816
# Epoch16, Loss :11.407588
# Epoch16, Loss :11.550353
# Epoch16, Loss :11.766852
# Epoch16, Loss :11.966387
# Epoch16, Loss :12.087032
# Epoch16, Loss :12.256838
# Epoch16, Loss :12.421574
# Epoch16, Loss :12.623394
# Epoch16, Loss :12.772081
# Epoch16, Loss :12.978389
# Epoch16, Loss :13.405335
# Epoch16, Loss :13.672658
# Epoch16, Loss :14.226728
# Epoch16, Loss :14.640924
# Epoch16, Loss :14.854766
# Epoch16, Loss :15.063536
# Epoch16, Loss :15.287071
# Epoch16, Loss :15.570895
# Epoch16, Loss :15.765513
# Epoch16, Loss :16.018873
# Epoch16, Loss :16.170267
# Epoch16, Loss :16.369321
# Epoch16, Loss :16.653172
# Epoch16, Loss :16.833021
# Epoch16, Loss :16.999963
# Epoch16, Loss :17.270135
# Epoch16, Loss :17.506910
# Epoch16, Loss :17.700101
# Epoch16, Loss :17.964894
# Epoch16, Loss :18.120426
# Epoch16, Loss :18.413660
# Epoch16, Loss :18.628676
# Epoch16, Loss :18.796393
# Epoch16, Loss :19.030800
# Epoch16, Loss :19.154716
# Epoch16, Loss :19.441685
# Epoch16, Loss :19.562129
# Epoch16, Loss :19.755758
# Epoch16, Loss :19.918154
# Epoch16, Loss :20.127534
# Epoch16, Loss :20.822139
# Epoch16, Loss :21.046522
# Epoch16, Loss :21.193662
# Epoch16, Loss :21.347419
# Epoch16, Loss :21.531652
# Epoch16, Loss :21.706413
# Epoch16, Loss :21.837483
# Epoch16, Loss :22.081508
# Epoch17, Loss :0.175428
# Epoch17, Loss :0.382176
# Epoch17, Loss :0.524467
# Epoch17, Loss :0.663064
# Epoch17, Loss :0.821594
# Epoch17, Loss :0.976835
# Epoch17, Loss :1.129585
# Epoch17, Loss :1.311386
# Epoch17, Loss :1.446867
# Epoch17, Loss :1.873835
# Epoch17, Loss :2.064108
# Epoch17, Loss :2.250851
# Epoch17, Loss :2.483492
# Epoch17, Loss :2.604902
# Epoch17, Loss :2.747474
# Epoch17, Loss :2.908302
# Epoch17, Loss :3.074076
# Epoch17, Loss :3.274885
# Epoch17, Loss :3.465952
# Epoch17, Loss :3.585015
# Epoch17, Loss :3.801300
# Epoch17, Loss :4.096157
# Epoch17, Loss :4.221258
# Epoch17, Loss :4.344447
# Epoch17, Loss :4.467274
# Epoch17, Loss :4.595948
# Epoch17, Loss :4.767110
# Epoch17, Loss :4.985004
# Epoch17, Loss :5.157461
# Epoch17, Loss :5.286611
# Epoch17, Loss :5.469550
# Epoch17, Loss :6.200916
# Epoch17, Loss :6.347607
# Epoch17, Loss :6.662813
# Epoch17, Loss :6.822440
# Epoch17, Loss :7.023852
# Epoch17, Loss :7.246065
# Epoch17, Loss :7.415888
# Epoch17, Loss :7.552451
# Epoch17, Loss :8.064893
# Epoch17, Loss :8.186151
# Epoch17, Loss :8.301508
# Epoch17, Loss :8.497382
# Epoch17, Loss :8.665616
# Epoch17, Loss :8.772768
# Epoch17, Loss :8.948219
# Epoch17, Loss :9.105958
# Epoch17, Loss :9.251342
# Epoch17, Loss :9.380594
# Epoch17, Loss :10.054760
# Epoch17, Loss :10.155684
# Epoch17, Loss :10.502036
# Epoch17, Loss :10.648831
# Epoch17, Loss :10.802603
# Epoch17, Loss :11.030759
# Epoch17, Loss :11.172635
# Epoch17, Loss :11.328777
# Epoch17, Loss :11.516615
# Epoch17, Loss :11.705222
# Epoch17, Loss :11.827349
# Epoch17, Loss :11.929337
# Epoch17, Loss :12.428233
# Epoch17, Loss :12.532878
# Epoch17, Loss :12.695007
# Epoch17, Loss :12.881709
# Epoch17, Loss :13.065638
# Epoch17, Loss :13.243906
# Epoch17, Loss :13.362333
# Epoch17, Loss :13.570720
# Epoch17, Loss :13.833395
# Epoch17, Loss :13.955633
# Epoch17, Loss :14.172818
# Epoch17, Loss :14.280289
# Epoch17, Loss :14.497695
# Epoch17, Loss :14.716937
# Epoch17, Loss :15.968548
# Epoch17, Loss :16.148602
# Epoch17, Loss :16.331326
# Epoch17, Loss :16.823596
# Epoch17, Loss :16.948170
# Epoch17, Loss :17.109728
# Epoch17, Loss :17.206820
# Epoch17, Loss :17.374169
# Epoch17, Loss :17.479859
# Epoch17, Loss :17.643498
# Epoch17, Loss :17.793194
# Epoch17, Loss :17.971197
# Epoch17, Loss :18.340854
# Epoch17, Loss :18.678870
# Epoch17, Loss :18.790737
# Epoch18, Loss :0.142886
# Epoch18, Loss :0.322506
# Epoch18, Loss :0.453547
# Epoch18, Loss :0.583357
# Epoch18, Loss :1.357099
# Epoch18, Loss :1.481905
# Epoch18, Loss :1.587135
# Epoch18, Loss :1.891596
# Epoch18, Loss :2.016429
# Epoch18, Loss :2.119145
# Epoch18, Loss :2.207531
# Epoch18, Loss :2.294120
# Epoch18, Loss :2.415195
# Epoch18, Loss :2.681586
# Epoch18, Loss :2.802788
# Epoch18, Loss :2.987098
# Epoch18, Loss :3.158650
# Epoch18, Loss :3.271385
# Epoch18, Loss :3.421258
# Epoch18, Loss :3.607933
# Epoch18, Loss :3.710505
# Epoch18, Loss :3.822173
# Epoch18, Loss :3.963056
# Epoch18, Loss :4.087545
# Epoch18, Loss :4.194880
# Epoch18, Loss :4.329021
# Epoch18, Loss :4.443995
# Epoch18, Loss :4.610344
# Epoch18, Loss :4.715758
# Epoch18, Loss :4.919996
# Epoch18, Loss :5.219555
# Epoch18, Loss :5.347542
# Epoch18, Loss :5.508541
# Epoch18, Loss :5.670243
# Epoch18, Loss :5.792157
# Epoch18, Loss :5.951788
# Epoch18, Loss :6.092689
# Epoch18, Loss :6.225842
# Epoch18, Loss :6.364156
# Epoch18, Loss :6.570310
# Epoch18, Loss :6.676636
# Epoch18, Loss :6.755080
# Epoch18, Loss :6.897217
# Epoch18, Loss :7.023418
# Epoch18, Loss :7.321072
# Epoch18, Loss :7.415809
# Epoch18, Loss :8.018674
# Epoch18, Loss :8.121376
# Epoch18, Loss :8.302426
# Epoch18, Loss :8.463992
# Epoch18, Loss :8.555034
# Epoch18, Loss :8.712207
# Epoch18, Loss :8.887083
# Epoch18, Loss :9.045036
# Epoch18, Loss :9.185391
# Epoch18, Loss :9.335182
# Epoch18, Loss :9.520806
# Epoch18, Loss :9.624354
# Epoch18, Loss :9.772377
# Epoch18, Loss :9.888616
# Epoch18, Loss :10.046438
# Epoch18, Loss :10.577889
# Epoch18, Loss :10.762921
# Epoch18, Loss :10.915198
# Epoch18, Loss :11.012733
# Epoch18, Loss :11.103018
# Epoch18, Loss :11.251135
# Epoch18, Loss :11.376437
# Epoch18, Loss :11.506558
# Epoch18, Loss :11.605556
# Epoch18, Loss :11.712974
# Epoch18, Loss :11.915237
# Epoch18, Loss :12.055470
# Epoch18, Loss :12.200345
# Epoch18, Loss :12.453161
# Epoch18, Loss :12.567196
# Epoch18, Loss :12.738594
# Epoch18, Loss :12.863398
# Epoch18, Loss :13.118446
# Epoch18, Loss :13.202225
# Epoch18, Loss :13.312971
# Epoch18, Loss :13.704257
# Epoch18, Loss :13.864444
# Epoch18, Loss :13.984806
# Epoch18, Loss :14.180459
# Epoch18, Loss :14.334740
# Epoch18, Loss :15.360253
# Epoch18, Loss :15.764625
# Epoch18, Loss :15.917942
# Epoch18, Loss :16.122657
# Epoch19, Loss :0.105507
# Epoch19, Loss :0.224107
# Epoch19, Loss :0.359787
# Epoch19, Loss :0.437903
# Epoch19, Loss :0.512151
# Epoch19, Loss :0.608881
# Epoch19, Loss :0.728115
# Epoch19, Loss :0.847796
# Epoch19, Loss :1.022387
# Epoch19, Loss :1.151919
# Epoch19, Loss :1.303354
# Epoch19, Loss :1.411528
# Epoch19, Loss :1.536107
# Epoch19, Loss :1.671515
# Epoch19, Loss :1.763429
# Epoch19, Loss :1.866463
# Epoch19, Loss :1.963367
# Epoch19, Loss :2.104598
# Epoch19, Loss :2.221642
# Epoch19, Loss :2.326245
# Epoch19, Loss :2.458086
# Epoch19, Loss :3.246893
# Epoch19, Loss :3.371811
# Epoch19, Loss :3.636757
# Epoch19, Loss :3.728005
# Epoch19, Loss :3.812656
# Epoch19, Loss :3.959504
# Epoch19, Loss :4.131506
# Epoch19, Loss :4.243516
# Epoch19, Loss :4.369773
# Epoch19, Loss :4.658667
# Epoch19, Loss :4.795376
# Epoch19, Loss :4.899267
# Epoch19, Loss :5.008795
# Epoch19, Loss :5.113525
# Epoch19, Loss :5.255881
# Epoch19, Loss :5.504078
# Epoch19, Loss :5.612580
# Epoch19, Loss :5.771946
# Epoch19, Loss :5.900418
# Epoch19, Loss :6.038142
# Epoch19, Loss :6.223703
# Epoch19, Loss :6.359857
# Epoch19, Loss :6.490415
# Epoch19, Loss :6.609765
# Epoch19, Loss :6.754925
# Epoch19, Loss :6.839041
# Epoch19, Loss :6.960488
# Epoch19, Loss :7.109398
# Epoch19, Loss :7.865723
# Epoch19, Loss :7.958227
# Epoch19, Loss :8.073993
# Epoch19, Loss :8.167587
# Epoch19, Loss :8.289011
# Epoch19, Loss :8.528778
# Epoch19, Loss :8.617472
# Epoch19, Loss :8.803662
# Epoch19, Loss :8.919464
# Epoch19, Loss :9.042798
# Epoch19, Loss :9.261494
# Epoch19, Loss :9.378249
# Epoch19, Loss :9.482932
# Epoch19, Loss :9.596606
# Epoch19, Loss :9.686016
# Epoch19, Loss :9.766357
# Epoch19, Loss :10.257667
# Epoch19, Loss :10.404130
# Epoch19, Loss :10.498332
# Epoch19, Loss :10.755443
# Epoch19, Loss :10.934007
# Epoch19, Loss :11.049127
# Epoch19, Loss :11.176118
# Epoch19, Loss :11.303983
# Epoch19, Loss :11.383180
# Epoch19, Loss :11.469159
# Epoch19, Loss :11.545372
# Epoch19, Loss :11.659929
# Epoch19, Loss :12.043235
# Epoch19, Loss :12.258995
# Epoch19, Loss :12.359828
# Epoch19, Loss :12.459191
# Epoch19, Loss :12.590504
# Epoch19, Loss :12.672620
# Epoch19, Loss :12.836571
# Epoch19, Loss :12.930005
# Epoch19, Loss :13.009642
# Epoch19, Loss :13.336407
# Epoch19, Loss :13.522205
# Epoch19, Loss :13.623466
# Epoch19, Loss :13.787554
# Epoch20, Loss :0.073214
# Epoch20, Loss :0.177079
# Epoch20, Loss :0.290702
# Epoch20, Loss :0.435356
# Epoch20, Loss :0.525475
# Epoch20, Loss :0.623907
# Epoch20, Loss :0.711894
# Epoch20, Loss :0.812305
# Epoch20, Loss :1.038198
# Epoch20, Loss :1.123442
# Epoch20, Loss :1.460149
# Epoch20, Loss :1.582319
# Epoch20, Loss :1.660184
# Epoch20, Loss :1.740234
# Epoch20, Loss :1.809610
# Epoch20, Loss :1.910066
# Epoch20, Loss :2.013767
# Epoch20, Loss :2.142566
# Epoch20, Loss :2.246560
# Epoch20, Loss :2.387201
# Epoch20, Loss :2.494912
# Epoch20, Loss :2.591403
# Epoch20, Loss :2.705359
# Epoch20, Loss :2.797940
# Epoch20, Loss :2.901661
# Epoch20, Loss :2.996918
# Epoch20, Loss :3.063909
# Epoch20, Loss :3.207953
# Epoch20, Loss :3.317862
# Epoch20, Loss :3.425920
# Epoch20, Loss :3.496704
# Epoch20, Loss :3.589937
# Epoch20, Loss :3.738209
# Epoch20, Loss :3.836254
# Epoch20, Loss :3.937212
# Epoch20, Loss :3.998653
# Epoch20, Loss :4.121939
# Epoch20, Loss :4.274017
# Epoch20, Loss :4.353471
# Epoch20, Loss :4.452800
# Epoch20, Loss :4.621129
# Epoch20, Loss :4.899242
# Epoch20, Loss :4.965163
# Epoch20, Loss :5.210568
# Epoch20, Loss :5.312434
# Epoch20, Loss :5.394329
# Epoch20, Loss :5.487476
# Epoch20, Loss :5.613837
# Epoch20, Loss :5.682317
# Epoch20, Loss :5.765869
# Epoch20, Loss :5.849071
# Epoch20, Loss :5.920528
# Epoch20, Loss :5.989489
# Epoch20, Loss :6.342180
# Epoch20, Loss :6.831834
# Epoch20, Loss :6.949383
# Epoch20, Loss :7.060431
# Epoch20, Loss :7.264487
# Epoch20, Loss :7.385296
# Epoch20, Loss :7.480940
# Epoch20, Loss :7.585155
# Epoch20, Loss :7.733363
# Epoch20, Loss :7.816592
# Epoch20, Loss :7.892372
# Epoch20, Loss :8.782194
# Epoch20, Loss :8.894745
# Epoch20, Loss :8.982159
# Epoch20, Loss :9.091547
# Epoch20, Loss :9.270467
# Epoch20, Loss :9.359565
# Epoch20, Loss :9.486986
# Epoch20, Loss :9.617145
# Epoch20, Loss :9.702910
# Epoch20, Loss :9.851432
# Epoch20, Loss :10.057755
# Epoch20, Loss :10.178760
# Epoch20, Loss :10.276490
# Epoch20, Loss :10.401449
# Epoch20, Loss :10.518412
# Epoch20, Loss :10.656452
# Epoch20, Loss :10.739538
# Epoch20, Loss :10.843499
# Epoch20, Loss :10.975303
# Epoch20, Loss :11.087685
# Epoch20, Loss :11.197774
# Epoch20, Loss :11.321721
# Epoch20, Loss :11.401353
# Epoch20, Loss :11.520134
# Epoch20, Loss :11.763856
# Epoch20, Loss :11.915156

# %%
def predict(model,question,threshold=0.6):
  numerical_questions = text_to_numerical(question,vocab)

  questions_tensor = torch.tensor(numerical_questions).unsqueeze(0)

  output = model(questions_tensor)

  probs = torch.nn.functional.softmax(output , dim=1)

  value,index =  torch.max(probs, dim=1)

  if value < threshold:
    print("i don't know")

  prediction = list(vocab.keys())[index]

  return prediction

# %%
print( predict(model, "what is the capital of japan"))
# Out:
# tokyo
